# %% [markdown]
# # Supply Input Materials
#
# This notebook generates the supply of the input variables for ILP in the repo.

# %%
#Importing libraries
import pandas as pd
import random
import csv
import os
from itertools import chain

#Setting random seed
random.seed(2)

# %%
#Setting workspace
os.chdir('/Users/dennisdekoning/Downloads/ILP/input data')

#Importing the different types of input materials
with open('input_materials.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

input_materials = list(chain.from_iterable(data))[1::]

#Determining time window
time = range(30)

#Setting average supply equal to average required materials
conversion_matrix = pd.read_csv('conversion_matrix.csv')

avg_supply = conversion_matrix.sum(axis=0)

# %% [markdown]
# As mentinoned suppy is generated randomly. To generate supply a random integer number is drawn between a lowerbound and an upperbound value. The lower- and upperbound are based on the material requirements for that specific input.

# %%
#Defining supply function 
def supply(alpha, input_materials, avg_supply, time):
    
    df = pd.DataFrame(index=time)
    for i, material in enumerate(input_materials):
        lowerbound = round(alpha*avg_supply[material] - alpha*0.5*avg_supply[material], 0)
        upperbound = round(alpha*avg_supply[material] + alpha*0.5*avg_supply[material], 0)
        df[material] = [random.randint(lowerbound, upperbound) for t in time]
        
    return df

# %%
#Priting supply matrix
supply(0.1, input_materials, avg_supply, time)
# Out:
#     material 01  material 02  material 03  material 04  material 05  \
# 0             4            3            2            9            4
# 1             5            6            3            8            8
# 2             5            6            2           12            3
# 3             9            4            2           13            3
# 4             6            6            2           10            3
# 5             8            7            3           14            3
# 6             8            6            3            6            3
# 7             7            3            3           10            3
# 8             4            5            3            5            8
# 9             6            5            2            8            3
# 10           10            7            2            6            5
# 11           10            6            3            5            5
# 12            9            4            1           14            4
# 13           11            6            2            5            4
# 14            8            4            3            9            8
# 15            4            4            1           14            4
# 16            4            5            3            8            7
# 17            9            3            2            6            8
# 18           11            5            2           13            3
# 19            9            7            2            7            6
# 20           10            7            2            9            7
# 21           10            5            3            8            3
# 22            6            7            3            8            4
# 23            6            6            3            5            4
# 24            7            3            3           11            3
# 25            7            5            3            5            3
# 26            4            4            3            5            5
# 27            6            5            3           10            7
# 28            9            6            3           10            8
# 29            6            6            2            7            8
#
#     material 06  material 07  material 08  material 09  material 10  ...  \
# 0             4            5            4           13            3  ...
# 1             7            3            6           13            2  ...
# 2             8            4            4            4            2  ...
# 3            10            4           10           10            4  ...
# 4             3            4           10           12            2  ...
# 5             7            3            6           13            4  ...
# 6            10            6            5            6            4  ...
# 7             3            8           12            5            2  ...
# 8             7            4            5           11            3  ...
# 9             9            7            7            9            5  ...
# 10            5            8            5            4            3  ...
# 11           10            3            5           12            2  ...
# 12            6            4            4            5            4  ...
# 13            4            4            6           13            5  ...
# 14            8            8            7            9            5  ...
# 15            4            6            5            8            3  ...
# 16            3            3            7            9            4  ...
# 17           10            5            4            8            5  ...
# 18            5            3           12            4            2  ...
# 19            9            7           11           10            4  ...
# 20           10            4           11            5            2  ...
# 21            8            7            8            5            2  ...
# 22            5            7           12            8            2  ...
# 23            8            8           10            7            4  ...
# 24            7            5            7            4            5  ...
# 25            7            5            7           11            3  ...
# 26            9            8           10            4            2  ...
# 27            3            6           10           10            2  ...
# 28            5            5           12           11            5  ...
# 29            3            7            4           11            2  ...
#
#     material 13  material 14  material 15  material 16  material 17  \
# 0             4            2            3            6            0
# 1             2            2            1            3            0
# 2             3            3            1            5            0
# 3             6            3            1            7            0
# 4             5            2            2            3            0
# 5             2            3            1            2            0
# 6             4            3            3            4            0
# 7             6            2            3            2            0
# 8             3            2            3            5            0
# 9             6            3            2            6            0
# 10            4            2            1            7            0
# 11            3            3            1            7            0
# 12            3            3            2            2            0
# 13            5            3            3            6            0
# 14            3            1            1            5            0
# 15            5            3            2            7            0
# 16            4            1            3            4            0
# 17            6            3            3            5            0
# 18            3            3            3            4            0
# 19            5            1            1            6            0
# 20            5            2            2            5            0
# 21            2            3            3            2            0
# 22            6            2            1            2            0
# 23            5            3            1            6            0
# 24            3            1            3            4            0
# 25            5            2            3            3            0
# 26            6            2            2            5            0
# 27            2            3            2            4            0
# 28            5            3            2            7            0
# 29            4            2            3            7            0
#
#     material 18  material 19  material 20  material 21  material 22
# 0             7            4            5            3            1
# 1             8            5            4            2            3
# 2             4            5            9            3            2
# 3             6            3            4            3            1
# 4             7            5            4            3            3
# 5             7            6            5            3            2
# 6             9            5            9            1            3
# 7             9            4            7            2            2
# 8             4            6            8            2            2
# 9             9            6            6            2            3
# 10            7            9            6            2            1
# 11            8            5            9            1            2
# 12            3            6            9            2            2
# 13            5            4            8            2            1
# 14            3            8            5            2            2
# 15            4            6            5            2            1
# 16            6            8            8            1            1
# 17            7            4            7            1            1
# 18            4            5            7            2            2
# 19            7            5            7            2            2
# 20            5            4            8            1            1
# 21            3            3            8            1            2
# 22            3            4            5            1            2
# 23            3            6            8            2            2
# 24            8            4            6            1            1
# 25            9            9            9            2            2
# 26            9            8            8            1            1
# 27            6            9            9            3            1
# 28            9            5            8            3            3
# 29            5            4            8            2            1
#
# [30 rows x 22 columns]

# %%
#Saving results as csv
supply(0.1,input_materials, avg_supply, time).to_csv('/Users/dennisdekoning/Downloads/supply_input_materials.csv')
